# %%
print("hello")
# Out:
# hello

# %%
from unsloth import FastLanguageModel
import torch
import json
import random
import os

# %%
model_name = 'unsloth/Phi-3-mini-4k-instruct-bnb-4bit'

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,
)
# Out:
# ==((====))==  Unsloth 2026.1.4: Fast Mistral patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA GeForce RTX 5070 Ti. Num GPUs = 1. Max memory: 15.447 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 12.0. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 model, tokenizer = FastLanguageModel.from_pretrained(
#       2     model_name = model_name,
#       3     max_seq_length = 2048,
#       4     dtype = None,
#       5     load_in_4bit = True,
#       6 )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth/models/loader.py:584, in FastLanguageModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, load_in_8bit, load_in_16bit, full_finetuning, token, device_map, rope_scaling, fix_tokenizer, trust_remote_code, use_gradient_checkpointing, resize_model_vocab, revision, use_exact_model_name, offload_embedding, float32_mixed_precision, fast_inference, gpu_memory_utilization, float8_kv_cache, random_state, max_lora_rank, disable_log_stats, qat_scheme, load_in_fp8, unsloth_tiled_mlp, *args, **kwargs)
#     581     load_in_4bit_kwargs = False
#     582     load_in_8bit_kwargs = False
# --> 584 model, tokenizer = dispatch_model.from_pretrained(
#     585     model_name = model_name,
#     586     max_seq_length = max_seq_length,
#     587     dtype = _get_dtype(dtype),
#     588     load_in_4bit = load_in_4bit_kwargs,
#     589     token = token,
#     590     device_map = device_map,
#     591     rope_scaling = rope_scaling,
#     592     fix_tokenizer = fix_tokenizer,
#     593     model_patcher = dispatch_model,
#     594     tokenizer_name = tokenizer_name,
#     595     trust_remote_code = trust_remote_code,
#     596     revision = revision if not is_peft else None,
#     597     fast_inference = fast_inference,
#     598     gpu_memory_utilization = gpu_memory_utilization,
#     599     float8_kv_cache = float8_kv_cache,
#     600     random_state = random_state,
#     601     max_lora_rank = max_lora_rank,
#     602     disable_log_stats = disable_log_stats,
#     603     *args,
#     604     **kwargs,
#     605 )
#     607 if resize_model_vocab is not None:
#     608     model.resize_token_embeddings(resize_model_vocab)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth/models/mistral.py:456, in FastMistralModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, model_patcher, tokenizer_name, trust_remote_code, **kwargs)
#     441 @staticmethod
#     442 def from_pretrained(
#     443     model_name = "unsloth/mistral-7b-bnb-4bit",
#    (...)    454     **kwargs,
#     455 ):
# --> 456     return FastLlamaModel.from_pretrained(
#     457         model_name = model_name,
#     458         max_seq_length = max_seq_length,
#     459         dtype = dtype,
#     460         load_in_4bit = load_in_4bit,
#     461         token = token,
#     462         device_map = device_map,
#     463         rope_scaling = rope_scaling,
#     464         fix_tokenizer = fix_tokenizer,
#     465         model_patcher = FastMistralModel,
#     466         tokenizer_name = tokenizer_name,
#     467         trust_remote_code = trust_remote_code,
#     468         **kwargs,
#     469     )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth/models/llama.py:2257, in FastLlamaModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, model_patcher, tokenizer_name, trust_remote_code, revision, fast_inference, gpu_memory_utilization, float8_kv_cache, random_state, max_lora_rank, disable_log_stats, unsloth_vllm_standby, num_labels, qat_scheme, **kwargs)
#    2255 model_patcher.pre_patch()
#    2256 # For debugging - we use a download counter to see if environments are not breaking or if HF is down
# -> 2257 get_statistics(kwargs.get("local_files_only", False))
#    2259 if dtype is None:
#    2260     dtype = torch.float16 if not SUPPORTS_BFLOAT16 else torch.bfloat16
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth/models/_utils.py:1232, in get_statistics(local_files_only)
#    1230     disable_progress_bars()
#    1231     disabled = True
# -> 1232 _get_statistics(None)
#    1233 _get_statistics("repeat", force_download = False)
#    1234 total_memory = (
#    1235     torch.xpu.get_device_properties(0).total_memory
#    1236     if DEVICE_TYPE == "xpu"
#    1237     else torch.cuda.get_device_properties(0).total_memory
#    1238 )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth/models/_utils.py:1189, in _get_statistics(statistics, force_download)
#    1187 time_limited_stats_check = execute_with_time_limit(120)(stats_check)
#    1188 try:
# -> 1189     time_limited_stats_check()
#    1190 except TimeoutError:
#    1191     raise TimeoutError(
#    1192         "Unsloth: HuggingFace seems to be down after trying for 120 seconds :(\n"
#    1193         "Check https://status.huggingface.co/ for more details.\n"
#    (...)   1200         "```"
#    1201     )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth_zoo/rl_environments.py:775, in execute_with_time_limit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     773         return func(*args, **kwargs)
#     774 elif effective_backend == "process":
# --> 775     return _run_in_subprocess(func, seconds, args, kwargs,
#     776                               start_method=start_method, kill_grace=kill_grace)
#     777 else:
#     778     raise ValueError("backend must be 'signal', 'process', or 'auto'")
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/unsloth_zoo/rl_environments.py:685, in _run_in_subprocess(func, seconds, args, kwargs, start_method, kill_grace)
#     681 child_conn.close()
#     683 try:
#     684     # Wait for result up to 'seconds'
# --> 685     if parent_conn.poll(seconds):
#     686         kind, payload = parent_conn.recv()
#     687         proc.join()
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/multiprocessing/connection.py:948, in wait(object_list, timeout)
#     945     deadline = time.monotonic() + timeout
#     947 while True:
# --> 948     ready = selector.select(timeout)
#     949     if ready:
#     950         return [key.fileobj for (key, events) in ready]
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
FastLanguageModel.for_inference(model)

# %%
categories = {
    "Information Technology": "laptop won't turn on, building web, building application, building software, wifi broken, server crash, screen, printer offline, install software, recover files, virus removal, coding help, password reset",
    "Cooking": "private chef needed, baking cakes, meal prep for week, catering for party, vegan menu, teaching how to cook, food delivery for event, baking lessons, dietary restrictions",
    "Handiworks": "assemble furniture, fix door handle, hang shelves, painting wall, repair fence, fix roof leak, drywall patch, carpentry, broken window, lock replacement",
    "Plumbing": "sink leaking, toilet clogged, low water pressure, pipe burst, install faucet, shower not draining, water heater broken, blocked drain, leak detection",
    "Electricity": "outlet not working, light switch broken, breaker keeps tripping, install ceiling fan, rewire house, flickering lights, install EV charger, fuse blown",
    "Cleaning": "deep clean apartment, carpet cleaning, window washing, move-out cleaning, office cleaning, power wash driveway, tidy up messy room, laundry service",
    "Education": "math tutor, piano lessons, learn spanish, sat prep, help with history homework, physics tutor, coding lessons, essay writing help, english teacher",
    "Well Being": "yoga instructor, meditation coach, life coaching, stress management, mindfulness session, spiritual guidance, relaxation techniques, personal mentor",
    "Health": "nursing care for elderly, feel sick, need medicine, physiotherapy, wound dressing, post-surgery care, check blood pressure, medical assistance, home nurse, injection service",
    "Accounting": "file taxes, bookkeeping for small business, audit assistance, financial planning, payroll help, quickbooks support, tax return, expense tracking"
}

# %%
generation_prompt = """You are a synthetic data generator. Generate 60 unique, diverse, and realistic user job requests for the category: "{category}".

Context keywords to inspire you: {keywords}

Rules:
1. The requests must sound like REAL customers (some angry, some polite, some urgent, some short, some detailed).
2. Do NOT number the list.
3. Output ONLY the requests, one per line.
4. Do not start lines with "I need" every time. Vary the phrasing.
5. Do not use the category name in the request (e.g., don't say "I need plumbing", say "my pipe burst").
"""

# %%
data = []

print(f"Starting generation for {len(categories)} categories...")

for cat, keywords in categories.items():
    print(f"--> Generating data for: {cat}...")

    for i in range(2): #the request ask LLM to generate 50 query once, twice means 100
        messages = [
            {"role": "user", "content": generation_prompt.format(category=cat, keywords=keywords)}
        ]
        inputs = tokenizer.apply_chat_template(
            messages, 
            tokenize=True, 
            add_generation_prompt=True, 
            return_tensors="pt"
        ).to("cuda")

        outputs = model.generate(
            inputs, 
            max_new_tokens=2048,
            temperature=0.9, # High temperature = more creativity/variety
            use_cache=True
        )
        
        # Decode output
        decoded_text = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
        
        # Extract the assistant's response (handling different Llama response formats)
        if "assistant" in decoded_text:
            raw_response = decoded_text.split("assistant")[-1].strip()
        else:
            raw_response = decoded_text
            
        lines = raw_response.split("\n")
        
        # Clean and filter lines
        count = 0
        for line in lines:
            line = line.strip()
            # Remove bullets, numbers, and garbage
            clean_line = line.lstrip("- ").lstrip("* ").lstrip("1234567890. ").strip()
            
            # Keep only valid-looking lines
            if len(clean_line) > 10 and not clean_line.startswith("Here is") and not clean_line.startswith("Sure"):
                data.append({"input": clean_line, "output": cat})
                count += 1
        
        print(f"    Batch {i+1}: Generated {count} examples")

# 5. SAVE TO FILE (JSONL format)
print(f"Shuffling and saving {len(data)} examples...")
random.shuffle(data)
# Out:
# Starting generation for 10 categories...
# --> Generating data for: Information Technology...
#     Batch 1: Generated 30 examples
#     Batch 2: Generated 30 examples
# --> Generating data for: Cooking...
#     Batch 1: Generated 89 examples
#     Batch 2: Generated 89 examples
# --> Generating data for: Handiworks...
#     Batch 1: Generated 118 examples
#     Batch 2: Generated 118 examples
# --> Generating data for: Plumbing...
#     Batch 1: Generated 69 examples
#     Batch 2: Generated 69 examples
# --> Generating data for: Electricity...
#     Batch 1: Generated 67 examples
#     Batch 2: Generated 67 examples
# --> Generating data for: Cleaning...
#     Batch 1: Generated 78 examples
#     Batch 2: Generated 78 examples
# --> Generating data for: Education...
#     Batch 1: Generated 131 examples
#     Batch 2: Generated 131 examples
# --> Generating data for: Well Being...
#     Batch 1: Generated 121 examples
#     Batch 2: Generated 121 examples
# --> Generating data for: Health...
#     Batch 1: Generated 79 examples
#     Batch 2: Generated 79 examples
# --> Generating data for: Accounting...
#     Batch 1: Generated 67 examples
#     Batch 2: Generated 67 examples
# Shuffling and saving 1698 examples...

# %%
with open("train3.jsonl", "w", encoding='utf-8') as f:
    for entry in data:
        json.dump(entry, f)
        f.write("\n")

print("Generating training data. Done")
# Out:
# Generating training data. Done

# %%
import json
import re

input_file = "train3.jsonl"
output_file = "train3_c.jsonl"


with open(input_file, 'r') as f_in, open(output_file, 'w') as f_out:
    for line in f_in:
        try:
            data = json.loads(line)
            data['input'] = data['input'].replace('\"', '') #clean /"
            data['input'] = re.sub(r'0{5,}', '', data['input']) #clean repeat character 
            f_out.write(json.dumps(data) + '\n')
        except json.JSONDecodeError:
            continue

print("Done")
# Out:
# Done

# %%
import pandas as pd
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
print("Loading training dataset")
df = pd.read_json("train3_c.jsonl", lines=True)
# Out:
# Loading training dataset

# %%
# TF-IDF: Converts text to math
# linear svc: The best algorithm for text classification
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(
        stop_words="english", 
        max_features=1000,
        ngram_range=(1,1),
        dtype='float32')
    ),
    ("clf", LinearSVC(class_weight='balanced')),
])

# %%
# 3. Train
print("2. Training Model...")
X_train, X_test, y_train, y_test = train_test_split(df['input'], df['output'], test_size=0.1, random_state=42)
pipeline.fit(X_train, y_train)

# 4. Test
print("3. Validating...")
accuracy = pipeline.score(X_test, y_test)
print(f"Accuracy: {accuracy:.2f}")
print(classification_report(y_test, pipeline.predict(X_test)))
# Out:
# 2. Training Model...
# 3. Validating...
# Accuracy: 0.95
#                         precision    recall  f1-score   support
#
#             Accounting       1.00      0.92      0.96        12
#               Cleaning       1.00      1.00      1.00        10
#                Cooking       1.00      0.93      0.97        15
#              Education       1.00      1.00      1.00        33
#            Electricity       1.00      0.78      0.88         9
#             Handiworks       1.00      0.88      0.93        32
#                 Health       1.00      1.00      1.00        18
# Information Technology       0.60      1.00      0.75         6
#               Plumbing       0.88      1.00      0.93        14
#             Well Being       0.91      1.00      0.95        21
#
#               accuracy                           0.95       170
#              macro avg       0.94      0.95      0.94       170
#           weighted avg       0.96      0.95      0.95       170
# /home/will/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:2043: UserWarning: Only (<class 'numpy.float64'>, <class 'numpy.float32'>, <class 'numpy.float16'>) 'dtype' should be used. float32 'dtype' will be converted to np.float64.
#   warnings.warn(

# %%
# 5. Save
joblib.dump(pipeline, "service_classifier.pkl")
print("Model saved")
# Out:
# Model saved to 'service_classifier.pkl' (Size: < 10MB)

# %%
my_text = "I need help with baking cakes"
prediction = pipeline.predict([my_text])
print(f"input: '{my_text}'")
print(f"predicted: {prediction[0]}") # [0] gets the string out of the array
# Out:
# Input: 'I need help with baking cakes'
# Predicted: Cooking

# %%
#predict from saved model

model = joblib.load("service_classifier.pkl")
user_input = "My house is dirty, and needs to be cleaned"
predict = model.predict([user_input])[0]

print(f"Category: {predict}")
# Out:
# Category: Cleaning

# %%
import requests
import json

API_URL = "http://170.64.179.146:8060/api/job/solution" 

# The data to insert
data = [
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Custom Business Website Development",
        "description": "Professional web design and development service. We create responsive, SEO-friendly websites tailored to your brand, including e-commerce capabilities and content management systems.",
        "price": 3500.00,
        "processedNumber": 42,
        "imageUrl": "https://cdn.mos.cms.futurecdn.net/wyJLsG4PQRoRPaXKVF3GuV.jpg"

    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Mobile App Development (iOS & Android)",
        "description": "Full-cycle mobile application development for startups and enterprises. We build high-performance native and cross-platform apps with user-friendly interfaces and secure backends.",
        "price": 8500.00,
        "processedNumber": 12,
        "imageUrl": "https://www.crunchgrowth.com/wp-content/uploads/2017/04/mobile_apps.jpg"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Laptop & Desktop Hardware Repair",
        "description": "Expert diagnosis and repair for computers that won't turn on, have broken screens, or faulty batteries. Service includes component replacement and hardware stress testing.",
        "price": 150.00,
        "processedNumber": 105,
        "imageUrl": "https://sifugeek.uk/wp-content/uploads/best-time-hardware-repairs-1024x682.jpg"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Data Recovery & Backup Solutions",
        "description": "Emergency file recovery for crashed hard drives, corrupted USBs, and accidental deletions. We also set up automated cloud backup systems to prevent future data loss.",
        "price": 300.00,
        "processedNumber": 67,
        "imageUrl": "https://buzzclan.com/wp-content/uploads/2025/07/Implementing-Enterprise-Data-Backup-and-Recovery_-Strategies-and-Solutions.svg"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Virus Removal & Cybersecurity Audit",
        "description": "Comprehensive security sweep to remove malware, ransomware, and spyware. Includes a security audit of your system and installation of premium antivirus software.",
        "price": 120.00,
        "processedNumber": 89,
        "imageUrl": "https://store.hp.com/app/assets/images/uploads/prod/how-to-remove-malware-on-windows-pc-hero1581530134837100.png"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Home Network & WiFi Optimization",
        "description": "Fix dead zones and slow internet speeds. We install mesh networks, configure routers for maximum security, and troubleshoot connectivity issues for all your smart devices.",
        "price": 180.00,
        "processedNumber": 210,
        "imageUrl": "https://images.squarespace-cdn.com/content/v1/69305b0b77844c5dcc769951/b265aec3-c2b2-479b-b1cf-975a2307365d/Wifi+Optimization.png"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Software Installation & OS Configuration",
        "description": "Hassle-free installation of operating systems (Windows, Linux, macOS) and professional software suites. We ensure all drivers are updated and settings are optimized for performance.",
        "price": 80.00,
        "processedNumber": 145,
        "imageUrl": "https://img.freepik.com/free-vector/flat-design-cms-concept-illustrated_23-2148796510.jpg?semt=ais_hybrid&w=740&q=80"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Server Maintenance & Cloud Management",
        "description": "Ongoing support for business servers and cloud infrastructure (AWS/Azure). Includes 24/7 monitoring, patch management, crash recovery, and performance tuning.",
        "price": 1200.00,
        "processedNumber": 8,
        "imageUrl": "https://img.freepik.com/premium-vector/cloud-server-maintenance-management_999616-59.jpg"
    },
    {
        "userId": 2,
        "categoryIds": [5],
        "solutionName": "Printer & Peripheral Setup",
        "description": "On-site support to get your offline printers, scanners, and external devices working perfectly. We handle driver conflicts and network configuration for wireless printing.",
        "price": 95.00,
        "processedNumber": 33,
        "imageUrl": "https://m.media-amazon.com/images/S/aplus-media-library-service-media/db8b2742-6d90-4e37-b97c-5a259fa86a00.__CR0,0,800,600_PT0_SX600_V1___.jpg"
    },
    {
        "userId": 2,
        "categoryIds": [5, 11],
        "solutionName": "1-on-1 Coding & Tech Tutoring",
        "description": "Personalized programming lessons for beginners and students. Learn Python, Java, or Web Development fundamentals with an experienced software engineer.",
        "price": 60.00,
        "processedNumber": 56,
        "imageUrl": "https://cdn.outschool.com/images/outschool-filestack-general/ucWZdOCkS0ekZVo6bBmC_ChatGPT%20Image%20Jul%2014%2C%202025%2C%2008_22_08%20PM.png?fit=crop&height=179&width=344&quality=80&strip=true"
    }
]

print(f"🚀 Starting bulk upload of {len(data)} solutions...")

for item in data:
    try:
        response = requests.post(API_URL, json=item)
        
        if response.status_code in [200, 201]:
            print(f"Created: {item['solutionName']}")
        else:
            print(f"Failed ({response.status_code}): {item['solutionName']}")
            print(f"Reason: {response.text}")
            
    except Exception as e:
        print(f"Error connecting to API: {e}")

print("\nFinished!")
# Out:
# 🚀 Starting bulk upload of 10 solutions...
# ✅ Created: Custom Business Website Development
# ✅ Created: Mobile App Development (iOS & Android)
# ✅ Created: Laptop & Desktop Hardware Repair
# ✅ Created: Data Recovery & Backup Solutions
# ✅ Created: Virus Removal & Cybersecurity Audit
# ✅ Created: Home Network & WiFi Optimization
# ✅ Created: Software Installation & OS Configuration
# ✅ Created: Server Maintenance & Cloud Management
# ✅ Created: Printer & Peripheral Setup
# ✅ Created: 1-on-1 Coding & Tech Tutoring
#
# Finished!
